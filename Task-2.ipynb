# %% [markdown]
# # Sejal S. Patil

# %% [markdown]
# # Data Science Internship CodSoft Sep-2023

# %% [markdown]
# # Task-2 Crdit Card Fraud Detection

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, classification_report
from sklearn.linear_model import LogisticRegression

# %%
cd = pd.read_csv("creditcard.csv")

# %%
cd
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
cd.describe()
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.758702e-12 -8.252296e-13 -9.637438e-13  8.316234e-13
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   1.592013e-13  4.247308e-13 -3.050183e-13  8.692882e-14 -1.179710e-12
# ...

# %%
cd.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
cd.head(10)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
# 6   4.0  1.229658  0.141004  0.045371  1.202613  0.191881  0.272708 -0.005159
# 7   7.0 -0.644269  1.417964  1.074380 -0.492199  0.948934  0.428118  1.120631
# 8   7.0 -0.894286  0.286157 -0.113192 -0.271526  2.669599  3.721818  0.370145
# 9   9.0 -0.338262  1.119593  1.044367 -0.222187  0.499361 -0.246761  0.651583
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# ...

# %%
cd.shape
# Out:
# (284807, 31)

# %%
cd.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
cd['Class'].value_counts()
# Out:
# 0    284315
# 1       492
# Name: Class, dtype: int64

# %%
# visualizing the class distribution

# %%
print((cd.groupby('Class')['Class'].count()/cd['Class'].count())*100)
((cd.groupby('Class')['Class'].count()/cd['Class'].count())*100).plot.pie()
# Out:
# Class
# 0    99.827251
# 1     0.172749
# Name: Class, dtype: float64
# <AxesSubplot:ylabel='Class'>

# %%
classes = cd['Class'].value_counts()
normal_value = round(classes[0]/cd['Class'].count()*100,2)
fraud_values = round(classes[1]/cd['Class'].count()*100,2)
print(normal_value)
print(fraud_values)
# Out:
# 99.83
# 0.17

# %%
# check the correlation

# %%
corr = cd.corr()
corr
# Out:
#             Time            V1            V2            V3            V4  \
# Time    1.000000  1.173963e-01 -1.059333e-02 -4.196182e-01 -1.052602e-01
# V1      0.117396  1.000000e+00  3.777823e-12 -2.118614e-12 -1.733159e-13
# V2     -0.010593  3.777823e-12  1.000000e+00  2.325661e-12 -2.314981e-12
# V3     -0.419618 -2.118614e-12  2.325661e-12  1.000000e+00  2.046235e-13
# V4     -0.105260 -1.733159e-13 -2.314981e-12  2.046235e-13  1.000000e+00
# V5      0.173072 -3.473231e-12 -1.831952e-12 -4.032993e-12 -2.552389e-13
# V6     -0.063016 -1.306165e-13  9.438444e-13 -1.574471e-13  1.084041e-12
# V7      0.084714 -1.116494e-13  5.403436e-12  3.405586e-12  8.135064e-13
# V8     -0.036949  2.114527e-12  2.133785e-14 -1.272385e-12  7.334818e-13
# V9     -0.008660  3.016285e-14  3.238513e-13 -6.812351e-13 -7.143069e-13
# V10     0.030617 -2.615192e-12  1.463282e-12 -1.609126e-12 -1.938143e-12
# V11    -0.247689  1.866551e-12 -8.314960e-13  8.707055e-13  1.874473e-12
# ...

# %%
# plotting the heatmap for the correlation
plt.figure(figsize=(27,19))
sns.heatmap(corr, cmap = 'spring', annot= True )
plt.show()

# %%
legit = cd[cd.Class == 0]

# %%
fraud = cd[cd.Class==1]

# %%
legit.Amount.describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
cd.groupby('Class').describe()
# Out:
#            Time                                                       \
#           count          mean           std    min      25%      50%
# Class
# 0      284315.0  94838.202258  47484.015786    0.0  54230.0  84711.0
# 1         492.0  80746.806911  47835.365138  406.0  41241.5  75568.5
#
#                                  V1            ...       V28             \
#             75%       max     count      mean  ...       75%        max
# Class                                          ...
# 0      139333.0  172792.0  284315.0  0.008258  ...  0.077962  33.847808
# 1      128483.0  170348.0     492.0 -4.771948  ...  0.381152   1.779364
#
#          Amount
#           count        mean         std  min   25%    50%     75%       max
# Class
# 0      284315.0   88.291022  250.105092  0.0  5.65  22.00   77.05  25691.16
# 1         492.0  122.211321  256.683288  0.0  1.00   9.25  105.89   2125.87
#
# [2 rows x 240 columns]

# %%
cd.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
normal_sample = legit.sample(n=492)

# %%
cd_new = pd.concat([normal_sample, fraud], axis = 0)

# %%
cd_new
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 57195    47802.0  0.026317 -1.388048  0.284323  3.086005 -0.909517  0.134568
# 74662    55691.0 -1.589598  1.842027 -1.193077  0.423548  0.961916  6.355986
# 52770    45633.0 -0.360615  0.997909  1.156833 -0.120812  0.153519 -0.497436
# 221822  142716.0  1.935471  0.597561 -0.758318  3.685668  0.609436  0.064402
# 43000    41331.0 -1.165317  0.130238  2.490593  0.632536  0.807173 -0.744875
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
cd_new['Class'].value_counts()
# Out:
# 0    492
# 1    492
# Name: Class, dtype: int64

# %%
cd_new.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97769.949187 -0.010058  0.066332 -0.041359 -0.001345  0.104458
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0     -0.001712  0.030837  0.071088  0.072125  ...  0.085421 -0.008691
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.019521 -0.022331 -0.009366 -0.006922  0.009183  0.014897  0.022866
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.022093
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
delta_time = pd.to_timedelta(cd_new['Time'], unit = 's')
# create the derived column
cd_new['time_hour']=(delta_time.dt.components.hours).astype(int)
# drop the time column
cd_new.drop(columns='Time', axis=1, inplace = True)

# %%
cd_new
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 57195   0.026317 -1.388048  0.284323  3.086005 -0.909517  0.134568  0.663805
# 74662  -1.589598  1.842027 -1.193077  0.423548  0.961916  6.355986 -5.203765
# 52770  -0.360615  0.997909  1.156833 -0.120812  0.153519 -0.497436  0.528644
# 221822  1.935471  0.597561 -0.758318  3.685668  0.609436  0.064402  0.237357
# 43000  -1.165317  0.130238  2.490593  0.632536  0.807173 -0.744875  0.286820
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 280143  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 280149 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 281144 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 281674  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
# ...

# %%
x = cd_new.drop('Class', axis=1)

# %%
y = cd_new['Class']

# %%
x.shape
# Out:
# (984, 30)

# %%
y.shape
# Out:
# (984,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.25, random_state = 3, stratify = y)

# %%
cols = list(x.columns.values)

# %%
normal_entries = cd_new.Class==0
fraud_entries = cd_new.Class==1

plt.figure(figsize=(20,70))
for n, col in enumerate(cols):
    plt.subplot(10,3,n+1)
    sns.histplot(x[col][normal_entries], color='blue', kde = True, stat = 'density')
    sns.histplot(x[col][fraud_entries], color='red', kde = True, stat = 'density')
    plt.title(col, fontsize=17)
plt.show()

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
y_pred = model.predict(x_train)
pred_test = model.predict(x_test)
# Out:
# C:\Users\User\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
from sklearn.metrics import confusion_matrix
def Plot_confusion_matrix(y_test, y_pred):
    cm = confusion_matrix(y_test,pred_test)
    plt.clf()
    plt.show()

# %%
acc_score= round(accuracy_score(y_pred, y_train)*100,2)

# %%
print('the accuracy score for training data of our model is :', acc_score)
# Out:
# the accuracy score for training data of our model is : 95.39

# %%
y_pred = model.predict(x_test)
acc_score = round(accuracy_score(y_pred, y_test)*100,2)

# %%
print('the accuracy score of our model is :', acc_score)
# Out:
# the accuracy score of our model is : 93.9

# %%
from sklearn import metrics

# %%
score = round(model.score(x_test, y_test)*100,2)
print('score of our model is :', score)
# Out:
# score of our model is : 93.9

# %%
class_report = classification_report(y_pred, y_test)
print('classification report of our model: ', class_report)
# Out:
# classification report of our model:                precision    recall  f1-score   support
#
#            0       0.98      0.91      0.94       132
#            1       0.90      0.97      0.94       114
#
#     accuracy                           0.94       246
#    macro avg       0.94      0.94      0.94       246
# weighted avg       0.94      0.94      0.94       246

# %% [markdown]
# # Thank You :)
